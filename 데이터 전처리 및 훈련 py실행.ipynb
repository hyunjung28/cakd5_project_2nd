# %%
# %tensorflow_version 1.x
# !pip install numpy==1.19.5
# !pip install h5py==2.10.0

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# bert_to_module.py로 버트모델 체크포인트 생성

# %%
# !python /content/drive/MyDrive/Colab_Notebooks/2nd_project/bert_slot_kor/export_korbert/bert_to_module.py -i /content/drive/MyDrive/Colab_Notebooks/2nd_project/dataset/004_bert_eojeol_tensorflow -o /content/drive/MyDrive/Colab_Notebooks/2nd_project/dataset/model

# %% [markdown]
# prepare_data.py로 data.txt 토큰화 및 태그화

# %%
# !python /content/drive/MyDrive/Colab_Notebooks/2nd_project/prepare_data.py -i /content/drive/MyDrive/Colab_Notebooks/2nd_project/dataset/data.txt -o /content/drive/MyDrive/Colab_Notebooks/2nd_project/dataset

# %% [markdown]
# data_split으로 8:1:1로 데이터 분리

# %%
# !python /content/drive/MyDrive/Colab_Notebooks/2nd_project/data_split.py -i /content/drive/MyDrive/Colab_Notebooks/2nd_project/dataset -o /content/drive/MyDrive/Colab_Notebooks/2nd_project/dataset

# %% [markdown]
# train.py로 파인튜닝 실행

# %%
# train 실행
# !python /content/drive/MyDrive/Colab_Notebooks/2nd_project/bert_slot_kor/train.py -t /content/drive/MyDrive/Colab_Notebooks/2nd_project/dataset/train -v /content/drive/MyDrive/Colab_Notebooks/2nd_project/dataset/validation -s /content/drive/MyDrive/Colab_Notebooks/2nd_project/dataset/saved_model -e 1

# %% [markdown]
# eval.py로 검증 실행

# %%
# eval 실행
# !python /content/drive/MyDrive/Colab_Notebooks/2nd_project/bert_slot_kor/eval.py -m /content/drive/MyDrive/Colab_Notebooks/2nd_project/dataset/saved_model -d /content/drive/MyDrive/Colab_Notebooks/2nd_project/dataset/test

# %% [markdown]
# inference.py로 문장을 넣어가며 검증 실행

# %%
# 문장 넣어서 예측하기
# !python /content/drive/MyDrive/Colab_Notebooks/2nd_project/bert_slot_kor/inference.py -m /content/drive/MyDrive/Colab_Notebooks/2nd_project/dataset/saved_model
